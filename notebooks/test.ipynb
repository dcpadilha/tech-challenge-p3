# %%
import pandas as pd
import opendatasets as od
from sklearn.preprocessing import MultiLabelBinarizer

# %%
def get_and_load(url, streaming=True):
    od.download(url, data_dir='downloads', force=True)
    folder_name = url.split('/')[-1]
    
    dataset_name = folder_name.split('-')[1]
    df = pd.read_csv(f'downloads/{folder_name}/data.csv')
    print(f'{dataset_name}: {df.shape}')

    if streaming:
        # Verifique o formato dos dados
        df['availableCountries'] = df['availableCountries'].apply(lambda x: x.split(',') if isinstance(x, str) else x)

        # Remova espaços em branco
        df['availableCountries'] = df['availableCountries'].apply(lambda x: [country.strip() for country in x])

        # Aplique o MultiLabelBinarizer
        mlb = MultiLabelBinarizer()
        transformed_array = mlb.fit_transform(df['availableCountries'])
        df = df.join(pd.DataFrame(transformed_array, columns=mlb.classes_))

        # Verifique a presença de BR
        df['contains_BR'] = df['availableCountries'].apply(lambda x: 'BR' in x)

        # Adiciona a coluna streaming
        df[f'on_{dataset_name}'] = 1

    return df

# %%
df_apple = get_and_load('https://www.kaggle.com/datasets/octopusteam/full-apple-tv-dataset')
df_amazon = get_and_load('https://www.kaggle.com/datasets/octopusteam/full-amazon-prime-dataset')
df_netflix = get_and_load('https://www.kaggle.com/datasets/octopusteam/full-netflix-dataset')
df_hbo = get_and_load('https://www.kaggle.com/datasets/octopusteam/full-hbo-max-dataset')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/octopusteam/full-apple-tv-dataset
# Downloading full-apple-tv-dataset.zip to downloads/full-apple-tv-dataset
# 100%|██████████| 424k/424k [00:00<00:00, 1.09MB/s]
# apple: (17766, 8)
# Dataset URL: https://www.kaggle.com/datasets/octopusteam/full-amazon-prime-dataset
# Downloading full-amazon-prime-dataset.zip to downloads/full-amazon-prime-dataset
# 100%|██████████| 1.92M/1.92M [00:00<00:00, 3.43MB/s]
# amazon: (67762, 8)
# Dataset URL: https://www.kaggle.com/datasets/octopusteam/full-netflix-dataset
# Downloading full-netflix-dataset.zip to downloads/full-netflix-dataset
# 100%|██████████| 751k/751k [00:00<00:00, 2.51MB/s]
# netflix: (20196, 8)
# Dataset URL: https://www.kaggle.com/datasets/octopusteam/full-hbo-max-dataset
# Downloading full-hbo-max-dataset.zip to downloads/full-hbo-max-dataset
# 100%|██████████| 169k/169k [00:00<00:00, 378kB/s]
# hbo: (5771, 8)

# %%
df_amazon.head()
# Out:
#             title   type                  genres  releaseYear     imdbId  \
# 0         Blondie  movie          Comedy, Family       1938.0  tt0029927
# 1           Ariel  movie  Comedy, Crime, Romance       1988.0  tt0094675
# 2      Four Rooms  movie                  Comedy       1995.0  tt0113101
# 3  Judgment Night  movie    Action, Crime, Drama       1993.0  tt0107286
# 4    Forrest Gump  movie          Drama, Romance       1994.0  tt0109830
#
#    imdbAverageRating  imdbNumVotes  \
# 0                6.9         886.0
# 1                7.4        8790.0
# 2                6.7      112688.0
# 3                6.6       19322.0
# 4                8.8     2321918.0
#
#                              availableCountries  AD  AE  ...  US  UY  VA  VE  \
# 0                                      [US, ZA]   0   0  ...   1   0   0   0
# 1                                          [JP]   0   0  ...   0   0   0   0
# 2                                      [AT, DE]   0   0  ...   0   0   0   0
# 3                                          [US]   0   0  ...   1   0   0   0
# 4  [AD, AT, CU, DE, FR, GF, IN, JP, MC, PF, SN]   1   0  ...   0   0   0   0
#
#    YE  ZA  ZM  ZW  contains_BR  on_amazon
# 0   0   1   0   0        False          1
# 1   0   0   0   0        False          1
# 2   0   0   0   0        False          1
# 3   0   0   0   0        False          1
# 4   0   0   0   0        False          1
#
# [5 rows x 142 columns]

# %%
df_apple.head()

# %%
df_hbo.head()

# %%
df_netflix.head()

# %%
dfs = pd.concat([df_apple, df_amazon, df_netflix, df_hbo])

# %%
dfs.title.nunique()

# %%
print(dfs.on_apple.value_counts())
print(dfs.on_amazon.value_counts())
print(dfs.on_hbo.value_counts())
print(dfs.on_netflix.value_counts())
# Out:
# on_apple
# 1.0    17766
# Name: count, dtype: int64
# on_amazon
# 1.0    67762
# Name: count, dtype: int64
# on_hbo
# 1.0    5771
# Name: count, dtype: int64
# on_netflix
# 1.0    20196
# Name: count, dtype: int64

# %%
dfs.BR.value_counts()
# Out:
# BR
# 0    94686
# 1    16809
# Name: count, dtype: int64

# %%
df_imdb = get_and_load('https://www.kaggle.com/datasets/octopusteam/full-imdb-dataset', streaming=False)

# %%
df_imdb.head()

# %%
df_imdb.id.nunique()

# %%
pd.merge(dfs, df_imdb, left_on='imdbId', right_on='id', how='inner')

# %%
dfs.shape

# %%
dfs.type.value_counts()

# %%
df_imdb.type.value_counts()

# %%
dfs[dfs.imdbId.isna()]
# Out:
#                                      title   type              genres  \
# 3133                           Siste trikk  movie                 NaN
# 3205                  El Arte De La Guerra  movie                 NaN
# 3215                            The Oracle  movie       Comedy, Drama
# 3230                         Clean Up Crew  movie         Documentary
# 3252  The Many Worlds of Quantum Mechanics  movie         Documentary
# ...                                    ...    ...                 ...
# 5757                                   NaN     tv                 NaN
# 5758                                   NaN     tv                 NaN
# 5759                                   NaN     tv  Crime, Documentary
# 5762                                   NaN     tv      Drama, Mystery
# 5768                                   NaN     tv             Reality
#
#       releaseYear imdbId  imdbAverageRating  imdbNumVotes  \
# 3133       2024.0    NaN                NaN           NaN
# 3205       2024.0    NaN                NaN           NaN
# 3215       2024.0    NaN                NaN           NaN
# 3230       2021.0    NaN                NaN           NaN
# 3252       2019.0    NaN                NaN           NaN
# ...           ...    ...                ...           ...
# 5757       2009.0    NaN                NaN           NaN
# 5758       2024.0    NaN                NaN           NaN
# 5759       2024.0    NaN                NaN           NaN
# 5762       2012.0    NaN                NaN           NaN
# 5768       2010.0    NaN                NaN           NaN
#
#                                      availableCountries   AE  AG  ...  TZ  \
# 3133                                           [DE, GB]  0.0   0  ... NaN
# 3205                                               [BR]  0.0   0  ... NaN
# 3215                                               [CA]  0.0   0  ... NaN
# 3230                                           [GB, US]  0.0   0  ... NaN
# 3252                                           [GB, US]  0.0   0  ... NaN
# ...                                                 ...  ...  ..  ...  ..
# 5757  [AR, BO, BR, CL, CO, CR, DO, EC, GT, HN, MX, N...  NaN   0  ... NaN
# 5758  [AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, E...  NaN   1  ... NaN
# 5759                                       [AR, ES, US]  NaN   0  ... NaN
# 5762                                               [NL]  NaN   0  ... NaN
# 5768  [AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, E...  NaN   1  ... NaN
#
#        UY  VA  YE  ZM  ZW  on_amazon   ME  on_netflix  on_hbo
# 3133  NaN NaN NaN NaN NaN        NaN  NaN         NaN     NaN
# 3205  NaN NaN NaN NaN NaN        NaN  NaN         NaN     NaN
# 3215  NaN NaN NaN NaN NaN        NaN  NaN         NaN     NaN
# 3230  NaN NaN NaN NaN NaN        NaN  NaN         NaN     NaN
# 3252  NaN NaN NaN NaN NaN        NaN  NaN         NaN     NaN
# ...   ...  ..  ..  ..  ..        ...  ...         ...     ...
# 5757  1.0 NaN NaN NaN NaN        NaN  0.0         NaN     1.0
# 5758  1.0 NaN NaN NaN NaN        NaN  0.0         NaN     1.0
# 5759  0.0 NaN NaN NaN NaN        NaN  0.0         NaN     1.0
# 5762  0.0 NaN NaN NaN NaN        NaN  0.0         NaN     1.0
# 5768  1.0 NaN NaN NaN NaN        NaN  0.0         NaN     1.0
#
# [8698 rows x 151 columns]
